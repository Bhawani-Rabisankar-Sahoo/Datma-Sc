# %%
import numpy as np

import pandas as pd 

import matplotlib.pyplot as plt

# %%
ds_csv = "https://raw.githubusercontent.com/Bhawani-Rabisankar-Sahoo/Datma-Sc/master/ds_salaries.csv"


pd.read_csv(ds_csv).head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...

# %%
df=pd.read_csv(ds_csv)

df.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.job_title
# Out:
# 0                Data Scientist
# 1    Machine Learning Scientist
# 2             Big Data Engineer
# 3          Product Data Analyst
# 4     Machine Learning Engineer
# Name: job_title, dtype: object

# %%
df.job_title.value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
df["salary"]>10000
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 602    True
# 603    True
# 604    True
# 605    True
# 606    True
# Name: salary, Length: 607, dtype: bool

# %%
df.drop(columns=["Unnamed: 0"])
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-36a2d75d2a25> in <module>()
# ----> 1 df.drop(axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4141         else:
#    4142             raise ValueError(
# ...

# %% [markdown]
# SORTING

# %%
df.sort_values("experience_level").head(15)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 113         113       2021               EN              PT
# 139         139       2021               EN              FT
# 134         134       2021               EN              FT
# 131         131       2021               EN              FT
# 130         130       2021               EN              FT
# 128         128       2021               EN              FT
# 124         124       2021               EN              PT
# 123         123       2021               EN              FT
# 122         122       2021               EN              FT
# 118         118       2021               EN              FT
# 115         115       2021               EN              FT
# 109         109       2021               EN              FT
# 98           98       2021               EN              FT
# 96           96       2021               EN              PT
# 94           94       2021               EN              FT
#
# ...

# %%
df.sort_values("job_title").head(15)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 77           77       2021               MI              PT
# 606         606       2022               MI              FT
# 96           96       2021               EN              PT
# 113         113       2021               EN              PT
# 244         244       2021               EN              FT
# 52           52       2020               EN              FT
# 277         277       2021               SE              FT
# 391         391       2022               MI              FT
# 561         561       2022               SE              FT
# 560         560       2022               SE              FT
# 368         368       2022               EX              FT
# 344         344       2022               EX              FT
# 82           82       2021               MI              FT
# 123         123       2021               EN              FT
# 525         525       2022               SE              FT
#
# ...

# %%
df.sort_values("salary").head(15)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 238         238       2021               EN              FT
# 185         185       2021               MI              FT
# 15           15       2020               MI              FT
# 124         124       2021               EN              PT
# 196         196       2021               EN              FT
# 521         521       2022               EN              FT
# 38           38       2020               EN              FT
# 96           96       2021               EN              PT
# 113         113       2021               EN              PT
# 184         184       2021               MI              FL
# 153         153       2021               EN              FT
# 45           45       2020               EN              PT
# 192         192       2021               MI              FT
# 62           62       2020               EN              PT
# 522         522       2022               MI              FT
#
# ...

# %%
df.sort_values("salary_currency").head(15)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 505         505       2022               EN              FT
# 503         503       2022               MI              FT
# 205         205       2021               MI              FT
# 271         271       2021               SE              FT
# 511         511       2022               MI              FT
# 452         452       2022               EX              FT
# 375         375       2022               EX              FT
# 451         451       2022               MI              FT
# 499         499       2022               EN              FT
# 255         255       2021               SE              FT
# 194         194       2021               SE              FT
# 240         240       2021               SE              FT
# 520         520       2022               MI              FT
# 82           82       2021               MI              FT
# 152         152       2021               MI              FT
#
# ...

# %% [markdown]
# STATISTICS

# %%
df.mean(axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Unnamed: 0          303.000000
# work_year          2021.405272
# salary           324000.062603
# salary_in_usd    112297.869852
# remote_ratio         70.922570
# dtype: float64

# %%
df.mad(axis=0)
# Out:
# Unnamed: 0          151.749588
# work_year             0.623142
# salary           391215.796732
# salary_in_usd     52584.270643
# remote_ratio         36.502474
# dtype: float64

# %%
df.median(axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Unnamed: 0          303.0
# work_year          2022.0
# salary           115000.0
# salary_in_usd    101570.0
# remote_ratio        100.0
# dtype: float64

# %%
df.mode(axis=0)
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0             0     2022.0               SE              FT  Data Scientist
# 1             1        NaN              NaN             NaN             NaN
# 2             2        NaN              NaN             NaN             NaN
# 3             3        NaN              NaN             NaN             NaN
# 4             4        NaN              NaN             NaN             NaN
# ..          ...        ...              ...             ...             ...
# 602         602        NaN              NaN             NaN             NaN
# 603         603        NaN              NaN             NaN             NaN
# 604         604        NaN              NaN             NaN             NaN
# 605         605        NaN              NaN             NaN             NaN
# 606         606        NaN              NaN             NaN             NaN
#
# ...

# %%
df.min(axis=0)
# Out:
# Unnamed: 0                                        0
# work_year                                      2020
# experience_level                                 EN
# employment_type                                  CT
# job_title             3D Computer Vision Researcher
# salary                                         4000
# salary_currency                                 AUD
# salary_in_usd                                  2859
# employee_residence                               AE
# remote_ratio                                      0
# company_location                                 AE
# company_size                                      L
# dtype: object

# %%
df.max(axis=0)
# Out:
# Unnamed: 0                             606
# work_year                             2022
# experience_level                        SE
# employment_type                         PT
# job_title             Staff Data Scientist
# salary                            30400000
# salary_currency                        USD
# salary_in_usd                       600000
# employee_residence                      VN
# remote_ratio                           100
# company_location                        VN
# company_size                             S
# dtype: object

# %%
df.abs
# Out:
# <bound method NDFrame.abs of      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.prod(axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Unnamed: 0       0
# work_year        0
# salary           0
# salary_in_usd    0
# remote_ratio     0
# dtype: int64

# %%
df.salary.idxmin()
# Out:
# 185

# %%
df.salary_in_usd.idxmin()
# Out:
# 176

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 'salary'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-686b83a6e1e5> in <module>()
# ----> 1 df.idxmin("salary")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in idxmin(self, axis, skipna)
#   10019         dtype: object
#   10020         """
# > 10021         axis = self._get_axis_number(axis)
#   10022
#   10023         res = self._reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
# ...

# %%
plt.plot(df.salary_in_usd)

# %%
plt.plot(df.salary)

# %%
plt.plot(df.salary_in_usd,df.salary)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-93ad02d470b4> in <module>
# ----> 1 fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
#       2
#       3 ax.scatter('a', 'b', c='c', s='d', data=data)
#       4
#       5 ax.set_xlabel('salary')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     544                                         frameon=frameon,
# ...
